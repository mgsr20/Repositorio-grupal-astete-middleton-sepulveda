# %%
/serie-histórica-empalmada-divisiones-ipc-diciembre-2009-a-diciembre-2023-xls (3)(Serie_Empalmada_Div_IPC).csv

# %%
html_content = '''
<!DOCTYPE html>
<html>
<head>
    <title>Flourish Chart Export</title>
</head>
<body>
    <div class="flourish-embed flourish-chart" data-src="visualisation/26224111"><script src="https://public.flourish.studio/resources/embed.js"></script><noscript><img src="https://public.flourish.studio/visualisation/26224111/thumbnail" width="100%" alt="chart visualization" /></noscript></div>
</body>
</html>
'''

with open('index.html', 'w') as f:
    f.write(html_content)

print("HTML file 'index.html' created successfully. You can download it from the file browser.")
# Out:
# HTML file 'index.html' created successfully. You can download it from the file browser.

# %%
output_file_path = 'database_ocupada_cleaned.xlsx'
df_ocupada.to_excel(output_file_path, index=False)
print(f"DataFrame saved to {output_file_path}")
# Out:
# DataFrame saved to database_ocupada_cleaned.xlsx

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')


df_cleaned = df.dropna(subset=['Year'])

df_filtered = df_cleaned[(df_cleaned['Year'] >= 2014) & (df_cleaned['Year'] <= 2024)]

display(df_filtered.head())
# Out:
#        Year Month Unnamed: 2                           Unnamed: 3 Unnamed: 4  \
# 592  2014.0     1          4         VIVIENDA Y SERVICIOS BÁSICOS      81.84
# 593  2014.0     1          5  EQUIPAMIENTO Y MANTENCIÓN DEL HOGAR      86.05
# 594  2014.0     1          6                                SALUD      81.63
# 595  2014.0     1          7                           TRANSPORTE      94.65
# 596  2014.0     1          8                       COMUNICACIONES     101.31
#
#     Unnamed: 5  Unnamed: 6 Year_Month
# 592        0.4         NaN     2014-1
# 593        0.1         NaN     2014-1
# 594        0.9         NaN     2014-1
# 595        1.1         NaN     2014-1
# 596          0         NaN     2014-1

# %%
import pandas as pd

file_path = '/serie-histórica-empalmada-divisiones-ipc-diciembre-2009-a-diciembre-2023-xls (3)(Serie_Empalmada_Div_IPC).csv'
df = pd.read_csv(file_path, encoding='latin1', header=2)


df.columns = df.columns.str.strip()


df = df.rename(columns={'Unnamed: 0': 'Year', 'Unnamed: 1': 'Month'})

df = df.iloc[1:].copy()


df['Year_Month'] = df['Year'].astype(str) + '-' + df['Month'].astype(str)

display(df.head())
# Out:
#    Year Month Unnamed: 2                           Unnamed: 3 Unnamed: 4  \
# 1  2009    12          1   ALIMENTOS Y BEBIDAS NO ALCOHÓLICAS      65.14
# 2  2009    12          2         BEBIDAS ALCOHÓLICAS Y TABACO      50.14
# 3  2009    12          3                  VESTUARIO Y CALZADO     201.61
# 4  2009    12          4         VIVIENDA Y SERVICIOS BÁSICOS      70.05
# 5  2009    12          5  EQUIPAMIENTO Y MANTENCIÓN DEL HOGAR      83.54
#
#   Unnamed: 5  Unnamed: 6 Year_Month
# 1        NaN         NaN    2009-12
# 2        NaN         NaN    2009-12
# 3        NaN         NaN    2009-12
# 4        NaN         NaN    2009-12
# 5        NaN         NaN    2009-12
