# %%
import numpy as np

import pandas as pd

df = pd.read_csv('magdalena_database_limpia_01.csv', sep=';')
engine='python'

df = df.dropna(how='all')

print(df.to_string())
# Out:
# 1          Año         Mes       Buzo    Polerón  Zapatillas        Top  Promedio Low Cost      Falda      Blusa    Zapatos     Bláiser  Promedio High Cost  IPC Vestuario y Calzado  Variación Mensual (%)
# 2         2014       Enero          7          5          12         23               11,8         11          3         15           1                 7,5                   121,73                   -2,8
# 3         2014     Febrero         10          8          14         23               13,8         12          3         18           1                 8,5                   122,94                    1,0
# 4         2014       Marzo          9         11          16         20               14,0         10          3         20           1                 8,5                   124,61                    1,4
# ...
